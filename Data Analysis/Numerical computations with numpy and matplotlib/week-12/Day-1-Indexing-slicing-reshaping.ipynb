# %%
scores =[70,20,60,40]
target_scores=[]
for score in scores:
    if score>=50:
        target_scores.append(score)
print(target_scores)
# Out:
# [70, 60]

# %%
import numpy  as  np

# %%
scores =np.array(scores)

# %%
scores
# Out:
# array([70, 20, 60, 40])

# %%
t=scores>=50

# %%
t
# Out:
# array([ True, False,  True, False])

# %%
scores
# Out:
# array([70, 20, 60, 40])

# %%
t
# Out:
# array([ True, False,  True, False])

# %%
scores[t]
# Out:
# array([70, 60])

# %%
scores
# Out:
# array([70, 20, 60, 40])

# %%
scores[np.array([True,False,True,True])] # Masking
# Out:
# array([70, 60, 40])

# %%
scores.mean()
# Out:
# np.float64(47.5)

# %%
scores<scores.mean()
# Out:
# array([False,  True, False,  True])

# %%
c=scores<scores.mean()

# %%
c
# Out:
# array([False,  True, False,  True])

# %%
scores
# Out:
# array([70, 20, 60, 40])

# %%
scores[c]
# Out:
# array([20, 40])

# %%
scores.max()-scores.min()
# Out:
# np.int64(50)

# %%
scores<scores.max()-scores.min()
# Out:
# array([False,  True, False,  True])

# %%
scores
# Out:
# array([70, 20, 60, 40])

# %%
scores[scores<scores.max()-scores.min()]

# %%
x=np.random.randint(2,50,(4,2))

# %%
x
# Out:
# array([[ 2, 38],
#        [47, 36],
#        [49, 33],
#        [33, 27]], dtype=int32)

# %%
x.mean()
# Out:
# np.float64(33.125)

# %%
x>x.mean()
# Out:
# array([[False,  True],
#        [ True,  True],
#        [ True, False],
#        [False, False]])

# %%
x
# Out:
# array([[ 2, 38],
#        [47, 36],
#        [49, 33],
#        [33, 27]], dtype=int32)

# %%
x[x>x.mean()]
# Out:
# array([38, 47, 36, 49], dtype=int32)

# %%
scores
# Out:
# array([70, 20, 60, 40])

# %%
scores>50 and scores<70
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 scores>50 and scores<70
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
scores>50 & scores<70
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 scores>50 & scores<70
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
(scores>50) & (scores<70)
# Out:
# array([False, False,  True, False])

# %%
scores[(scores>50) & (scores<70)]
# Out:
# array([60])

# %%
scores[(scores>50) | (scores<70)]
# Out:
# array([70, 20, 60, 40])

# %%
scores>60
# Out:
# array([ True, False, False, False])

# %%
~(scores>60)
# Out:
# array([False,  True,  True,  True])

# %%
scores[~(scores>60)]
# Out:
# array([20, 60, 40])

# %%
## Indexing and slicing

# %%
scores
# Out:
# array([70, 20, 60, 40])

# %%
scores[0]
# Out:
# np.int64(70)

# %%
scores[1]
# Out:
# np.int64(20)

# %%
scores
# Out:
# array([70, 20, 60, 40])

# %%
scores[0:3:2]
# Out:
# array([70, 60])

# %%
## fancy indexing

# %%
scores[0,1,3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 scores[0,1,3]
#
# IndexError: too many indices for array: array is 1-dimensional, but 3 were indexed

# %%
scores[[0,1,3]]
# Out:
# array([70, 20, 40])

# %%
v= np.random.randint(0,100,12)

# %%
v
# Out:
# array([43, 61, 37, 80, 51, 59, 35, 42,  6, 39, 62, 43], dtype=int32)

# %%
scores(0,1,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 scores(0,1,3)
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
x
# Out:
# array([[ 2, 38],
#        [47, 36],
#        [49, 33],
#        [33, 27]], dtype=int32)

# %%
x[0][0]
# Out:
# np.int32(2)

# %%
x[0]
# Out:
# array([ 2, 38], dtype=int32)

# %%
x[0][0]
# Out:
# np.int32(2)

# %%
x[2][1]
# Out:
# np.int32(33)

# %%
x[0,0]
# Out:
# np.int32(2)

# %%
x[2,1]
# Out:
# np.int32(33)

# %%
x[:,0]
# Out:
# array([ 2, 47, 49, 33], dtype=int32)

# %%
x
# Out:
# array([[ 2, 38],
#        [47, 36],
#        [49, 33],
#        [33, 27]], dtype=int32)

# %%
x[:,-1]
# Out:
# array([38, 36, 33, 27], dtype=int32)

# %%
x[0:2,:]
# Out:
# array([[ 2, 38],
#        [47, 36]], dtype=int32)

# %%
scores
# Out:
# array([70, 20, 60, 40])

# %%
scores[0:2]
# Out:
# array([70, 20])

# %%
x[1:4:2,1]
# Out:
# array([36, 27], dtype=int32)

# %%
x
# Out:
# array([[ 2, 38],
#        [47, 36],
#        [49, 33],
#        [33, 27]], dtype=int32)

# %%
# reshaping

# %%
x
# Out:
# array([[ 2, 38],
#        [47, 36],
#        [49, 33],
#        [33, 27]], dtype=int32)

# %%
x.shape
# Out:
# (4, 2)

# %%
x.size
# Out:
# 8

# %%
x
# Out:
# array([[ 2, 38],
#        [47, 36],
#        [49, 33],
#        [33, 27]], dtype=int32)

# %%
x.reshape(2,4)
# Out:
# array([[ 2, 38, 47, 36],
#        [49, 33, 33, 27]], dtype=int32)

# %%
x.reshape(1,8)
# Out:
# array([[ 2, 38, 47, 36, 49, 33, 33, 27]], dtype=int32)

# %%
x.reshape(8,1)
# Out:
# array([[ 2],
#        [38],
#        [47],
#        [36],
#        [49],
#        [33],
#        [33],
#        [27]], dtype=int32)

# %%
x.reshape(2,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 x.reshape(2,3)
#
# ValueError: cannot reshape array of size 8 into shape (2,3)

# %%
x.reshape(2,-1)
# Out:
# array([[ 2, 38, 47, 36],
#        [49, 33, 33, 27]], dtype=int32)

# %%
x.reshape(-1,1)
# Out:
# array([[ 2],
#        [38],
#        [47],
#        [36],
#        [49],
#        [33],
#        [33],
#        [27]], dtype=int32)

# %%
x.reshape(3,-1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 x.reshape(3,-1)
#
# ValueError: cannot reshape array of size 8 into shape (3,newaxis)
