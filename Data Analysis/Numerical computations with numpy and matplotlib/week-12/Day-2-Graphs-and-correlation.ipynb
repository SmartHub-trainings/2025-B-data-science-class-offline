# %%
import numpy as np

# %%
x= np.random.randint(1,30,20)

# %%
x
# Out:
# array([ 3, 29,  1, 19,  5, 13, 11,  3, 13, 19, 24,  9, 17,  2, 25,  6,  7,
#         3, 10,  4], dtype=int32)

# %%
x.shape
# Out:
# (20,)

# %%
x.size
# Out:
# 20

# %%
x.reshape(4,5)
# Out:
# array([[ 3, 29,  1, 19,  5],
#        [13, 11,  3, 13, 19],
#        [24,  9, 17,  2, 25],
#        [ 6,  7,  3, 10,  4]], dtype=int32)

# %%
x.reshape(5,4)
# Out:
# array([[ 3, 29,  1, 19],
#        [ 5, 13, 11,  3],
#        [13, 19, 24,  9],
#        [17,  2, 25,  6],
#        [ 7,  3, 10,  4]], dtype=int32)

# %%
x.reshape(2,10)
# Out:
# array([[ 3, 29,  1, 19,  5, 13, 11,  3, 13, 19],
#        [24,  9, 17,  2, 25,  6,  7,  3, 10,  4]], dtype=int32)

# %%
y=x.reshape(10,2)

# %%
x.reshape(1,20)
# Out:
# array([[ 3, 29,  1, 19,  5, 13, 11,  3, 13, 19, 24,  9, 17,  2, 25,  6,
#          7,  3, 10,  4]], dtype=int32)

# %%
x
# Out:
# array([ 3, 29,  1, 19,  5, 13, 11,  3, 13, 19, 24,  9, 17,  2, 25,  6,  7,
#         3, 10,  4], dtype=int32)

# %%
y
# Out:
# array([[ 3, 29],
#        [ 1, 19],
#        [ 5, 13],
#        [11,  3],
#        [13, 19],
#        [24,  9],
#        [17,  2],
#        [25,  6],
#        [ 7,  3],
#        [10,  4]], dtype=int32)

# %%
x
# Out:
# array([ 3, 29,  1, 19,  5, 13, 11,  3, 13, 19, 24,  9, 17,  2, 25,  6,  7,
#         3, 10,  4], dtype=int32)

# %%
x.shape=(4,5)

# %%
x
# Out:
# array([[ 3, 29,  1, 19,  5],
#        [13, 11,  3, 13, 19],
#        [24,  9, 17,  2, 25],
#        [ 6,  7,  3, 10,  4]], dtype=int32)

# %%
x
# Out:
# array([[ 3, 29,  1, 19,  5],
#        [13, 11,  3, 13, 19],
#        [24,  9, 17,  2, 25],
#        [ 6,  7,  3, 10,  4]], dtype=int32)

# %%
x.ravel()
# Out:
# array([ 3, 29,  1, 19,  5, 13, 11,  3, 13, 19, 24,  9, 17,  2, 25,  6,  7,
#         3, 10,  4], dtype=int32)

# %%
x=x.ravel()

# %%
x
# Out:
# array([ 3, 29,  1, 19,  5, 13, 11,  3, 13, 19, 24,  9, 17,  2, 25,  6,  7,
#         3, 10,  4], dtype=int32)

# %%
y
# Out:
# array([[ 3, 29],
#        [ 1, 19],
#        [ 5, 13],
#        [11,  3],
#        [13, 19],
#        [24,  9],
#        [17,  2],
#        [25,  6],
#        [ 7,  3],
#        [10,  4]], dtype=int32)

# %%
y.flatten()
# Out:
# array([ 3, 29,  1, 19,  5, 13, 11,  3, 13, 19, 24,  9, 17,  2, 25,  6,  7,
#         3, 10,  4], dtype=int32)

# %%
y.ravel()
# Out:
# array([ 3, 29,  1, 19,  5, 13, 11,  3, 13, 19, 24,  9, 17,  2, 25,  6,  7,
#         3, 10,  4], dtype=int32)

# %%
y
# Out:
# array([[ 3, 29],
#        [ 1, 19],
#        [ 5, 13],
#        [11,  3],
#        [13, 19],
#        [24,  9],
#        [17,  2],
#        [25,  6],
#        [ 7,  3],
#        [10,  4]], dtype=int32)

# %%
y.T
# Out:
# array([[ 3,  1,  5, 11, 13, 24, 17, 25,  7, 10],
#        [29, 19, 13,  3, 19,  9,  2,  6,  3,  4]], dtype=int32)

# %%
y
# Out:
# array([[ 3, 29],
#        [ 1, 19],
#        [ 5, 13],
#        [11,  3],
#        [13, 19],
#        [24,  9],
#        [17,  2],
#        [25,  6],
#        [ 7,  3],
#        [10,  4]], dtype=int32)

# %%
z=y.T

# %%
z
# Out:
# array([[ 3,  1,  5, 11, 13, 24, 17, 25,  7, 10],
#        [29, 19, 13,  3, 19,  9,  2,  6,  3,  4]], dtype=int32)

# %% [markdown]
# ## Unstacking/splitting

# %%
y
# Out:
# array([[ 3, 29],
#        [ 1, 19],
#        [ 5, 13],
#        [11,  3],
#        [13, 19],
#        [24,  9],
#        [17,  2],
#        [25,  6],
#        [ 7,  3],
#        [10,  4]], dtype=int32)

# %%
np.hsplit(z,[3,5])
# Out:
# [array([[ 3,  1,  5],
#         [29, 19, 13]], dtype=int32),
#  array([[11, 13],
#         [ 3, 19]], dtype=int32),
#  array([[24, 17, 25,  7, 10],
#         [ 9,  2,  6,  3,  4]], dtype=int32)]

# %%
z
# Out:
# array([[ 3,  1,  5, 11, 13, 24, 17, 25,  7, 10],
#        [29, 19, 13,  3, 19,  9,  2,  6,  3,  4]], dtype=int32)

# %%
np.hsplit(z,[5])
# Out:
# [array([[ 3,  1,  5, 11, 13],
#         [29, 19, 13,  3, 19]], dtype=int32),
#  array([[24, 17, 25,  7, 10],
#         [ 9,  2,  6,  3,  4]], dtype=int32)]

# %%
np.vsplit(y,[2,8])
# Out:
# [array([[ 3, 29],
#         [ 1, 19]], dtype=int32),
#  array([[ 5, 13],
#         [11,  3],
#         [13, 19],
#         [24,  9],
#         [17,  2],
#         [25,  6]], dtype=int32),
#  array([[ 7,  3],
#         [10,  4]], dtype=int32)]

# %%
x
# Out:
# array([ 3, 29,  1, 19,  5, 13, 11,  3, 13, 19, 24,  9, 17,  2, 25,  6,  7,
#         3, 10,  4], dtype=int32)

# %%
ages = x

# %%
from matplotlib import pyplot as plt

# %%
plt.hist(ages)
# Out:
# (array([5., 3., 2., 2., 2., 1., 2., 0., 2., 1.]),
#  array([ 1. ,  3.8,  6.6,  9.4, 12.2, 15. , 17.8, 20.6, 23.4, 26.2, 29. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(ages,bins=5)
# Out:
# (array([8., 4., 3., 2., 3.]),
#  array([ 1. ,  6.6, 12.2, 17.8, 23.4, 29. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(ages,bins=[0,10,15,23,40])
# Out:
# (array([10.,  4.,  3.,  3.]),
#  array([ 0., 10., 15., 23., 40.]),
#  <BarContainer object of 4 artists>)

# %%
ages = np.random.randint(10,100,20)
weights = np.random.randint(40,150,20)

# %%
ages
# Out:
# array([87, 14, 72, 30, 53, 49, 21, 48, 44, 87, 63, 47, 43, 13, 45, 95, 10,
#        29, 17, 38], dtype=int32)

# %%
weights
# Out:
# array([129, 109, 138, 136, 101,  45,  56, 129,  93, 134,  89, 132,  49,
#         74,  55,  86,  64, 145, 102,  55], dtype=int32)

# %%
plt.scatter(ages,weights)

# %%
plt.scatter(ages,weights,marker="x")

# %%
plt.scatter(ages,weights,marker="^")

# %%
plt.scatter(ages,weights,s=200,marker="x")

# %%
plt.scatter(ages,weights,s=200,alpha=0.5)

# %%
np.corrcoef(ages,weights)
# Out:
# array([[1.        , 0.28430891],
#        [0.28430891, 1.        ]])
