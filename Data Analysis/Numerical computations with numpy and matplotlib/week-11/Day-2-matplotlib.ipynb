# %%
import numpy as np

# %%
x= np.linspace(-20,20,30)

# %%
x
# Out:
# array([-20.        , -18.62068966, -17.24137931, -15.86206897,
#        -14.48275862, -13.10344828, -11.72413793, -10.34482759,
#         -8.96551724,  -7.5862069 ,  -6.20689655,  -4.82758621,
#         -3.44827586,  -2.06896552,  -0.68965517,   0.68965517,
#          2.06896552,   3.44827586,   4.82758621,   6.20689655,
#          7.5862069 ,   8.96551724,  10.34482759,  11.72413793,
#         13.10344828,  14.48275862,  15.86206897,  17.24137931,
#         18.62068966,  20.        ])

# %%
y_sine= np.sin(x)

# %%
y_sine
# Out:
# array([-0.91294525,  0.2268735 ,  0.99930144,  0.15349646, -0.94087518,
#        -0.51162728,  0.7461315 ,  0.79563168, -0.44328555, -0.96436206,
#         0.07621478,  0.99337213,  0.30189827, -0.87845883, -0.6362712 ,
#         0.6362712 ,  0.87845883, -0.30189827, -0.99337213, -0.07621478,
#         0.96436206,  0.44328555, -0.79563168, -0.7461315 ,  0.51162728,
#         0.94087518, -0.15349646, -0.99930144, -0.2268735 ,  0.91294525])

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(x,y_sine)

# %%
plt.plot(x,y_sine)

# %%
x= np.linspace(-20,20,100)
y_sine= np.sin(x)
plt.scatter(x,y_sine)

# %%
y_sine
# Out:
# array([-0.91294525, -0.67900297, -0.33571414,  0.06163804,  0.44906404,
#         0.76417283,  0.95621934,  0.99427643,  0.87221538,  0.6096929 ,
#         0.24898556, -0.15181837, -0.5281735 , -0.81947165, -0.9788022 ,
#        -0.98050658, -0.82431033, -0.53536727, -0.16020873,  0.24074979,
#         0.60293801,  0.86802917,  0.99333304,  0.95867071,  0.76962418,
#         0.45663749,  0.07011396, -0.32770071, -0.6727425 , -0.90944594,
#        -0.99969234, -0.92894843, -0.7086068 , -0.37415123,  0.0205576 ,
#         0.41195583,  0.73701276,  0.94338126,  0.99782778,  0.89158426,
#         0.64176014,  0.28858706, -0.11106004, -0.49282204, -0.79522006,
#        -0.96955595, -0.98775469, -0.84688556, -0.56963411, -0.20064886,
#         0.20064886,  0.56963411,  0.84688556,  0.98775469,  0.96955595,
#         0.79522006,  0.49282204,  0.11106004, -0.28858706, -0.64176014,
#        -0.89158426, -0.99782778, -0.94338126, -0.73701276, -0.41195583,
# ...

# %%
plt.plot(x,y_sine)

# %%
x= np.linspace(-10,10,1000)
y_sine= np.sin(x)
# plt.scatter(x,y_sine)

# %%
plt.figure(figsize=(60,5))
plt.plot(x,y_sine)

# %%
y_sine
# Out:
# array([ 0.98803162,  0.99550892,  0.99939629,  0.99967971,  0.99635816,
#         0.98944361,  0.978961  ,  0.96494814,  0.94745555,  0.92654632,
#         0.90229584,  0.87479157,  0.84413269,  0.81042977,  0.77380432,
#         0.73438845,  0.69232427,  0.64776349,  0.60086679,  0.55180329,
#         0.50074991,  0.44789077,  0.39341648,  0.33752347,  0.28041332,
#         0.22229196,  0.16336898,  0.10385688,  0.04397026, -0.01607493,
#        -0.07606215, -0.13577508, -0.19499839, -0.2535185 , -0.3111244 ,
#        -0.36760835, -0.42276665, -0.4764004 , -0.52831619, -0.57832681,
#        -0.6262519 , -0.67191866, -0.71516239, -0.75582715, -0.7937663 ,
#        -0.82884304, -0.86093086, -0.88991405, -0.9156881 , -0.93816007,
#        -0.95724891, -0.97288579, -0.98501432, -0.99359076, -0.99858419,
#        -0.9999766 , -0.99776297, -0.99195128, -0.98256248, -0.96963044,
#        -0.95320179, -0.93333578, -0.91010403, -0.88359034, -0.85389031,
# ...

# %%
len(x)
# Out:
# 1000

# %%
y_exp= np.e**x
y_exp = np.exp(x)

# %%
np.e
# Out:
# 2.718281828459045

# %%
np.exp(1)
# Out:
# np.float64(2.718281828459045)

# %%
y_exp.shape
# Out:
# (1000,)

# %%
plt.plot(x,y_exp)

# %%
y_sigmoid= np.exp(x)/(1+np.exp(x))
plt.plot(x,y_sigmoid)
plt.grid()

# %%
y_sine=np.sin(x)
y_cos= np.cos(x)

# %%
plt.plot(x,y_sine)

# %%
plt.plot(x,y_cos)

# %%
plt.plot(x,y_cos,label="cosine")
plt.plot(x,y_sine,label="Sine")
plt.xlabel("Angles")
plt.ylabel("values")
plt.title("Multi sinusoidal curve")

plt.legend()
plt.grid()
