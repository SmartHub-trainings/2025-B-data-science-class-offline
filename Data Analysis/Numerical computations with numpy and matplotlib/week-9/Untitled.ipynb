# %%
import numpy as np

# %%
A= np.random.randint(2,10,(3,3))

# %%
A
# Out:
# array([[6, 7, 9],
#        [4, 7, 6],
#        [3, 3, 3]])

# %%
A.trace()
# Out:
# 16

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
range(1,7,0.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_38079/752358373.py in <module>
# ----> 1 range(1,7,0.5)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
np.arange(1,7,0.5)
# Out:
# array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5])

# %%
a=np.arange(4)

# %%
a
# Out:
# array([0, 1, 2, 3])

# %%
b=np.arange(1,6)

# %%
b
# Out:
# array([1, 2, 3, 4, 5])

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_38079/3553919051.py in <module>
# ----> 1 a+b
#
# ValueError: operands could not be broadcast together with shapes (4,) (5,)

# %%
c=np.random.randint(2,9,4)

# %%
c
# Out:
# array([7, 6, 3, 4])

# %%
a
# Out:
# array([0, 1, 2, 3])

# %%
a+c
# Out:
# array([7, 7, 5, 7])

# %%
c-a
# Out:
# array([7, 5, 1, 1])

# %%
a.ndim
# Out:
# 1

# %%
A=np.random.randint(3,8,(2,3))
B=np.random.randint(3,12,(2,3))

# %%
A
# Out:
# array([[5, 5, 3],
#        [4, 6, 7]])

# %%
B
# Out:
# array([[11,  8, 10],
#        [10,  6,  3]])

# %%
A+B
# Out:
# array([[16, 13, 13],
#        [14, 12, 10]])

# %%
A/B
# Out:
# array([[0.45454545, 0.625     , 0.3       ],
#        [0.4       , 1.        , 2.33333333]])

# %%
a
# Out:
# array([0, 1, 2, 3])

# %%
a+3
# Out:
# array([3, 4, 5, 6])

# %%
2*a
# Out:
# array([0, 2, 4, 6])

# %%
d=np.array([4])

# %%
d
# Out:
# array([4])

# %%
a+d
# Out:
# array([4, 5, 6, 7])

# %%
A
# Out:
# array([[5, 5, 3],
#        [4, 6, 7]])

# %%
v1=np.array([3,4])
v2=np.array([3,4,-1])

# %%
A
# Out:
# array([[5, 5, 3],
#        [4, 6, 7]])

# %%
A+v1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_38079/2049992188.py in <module>
# ----> 1 A+v1
#
# ValueError: operands could not be broadcast together with shapes (2,3) (2,)

# %%
A+v2
# Out:
# array([[ 8,  9,  2],
#        [ 7, 10,  6]])

# %%
a
# Out:
# array([0, 1, 2, 3])

# %%
c
# Out:
# array([7, 6, 3, 4])

# %%
a*c
# Out:
# array([ 0,  6,  6, 12])

# %%
A=np.array([[2,3],[1,4]])
B=np.array([[2,1,7],[1,2,-2]])

# %%
A
# Out:
# array([[2, 3],
#        [1, 4]])

# %%
B
# Out:
# array([[ 2,  1,  7],
#        [ 1,  2, -2]])

# %%
A*B
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_38079/786576050.py in <module>
# ----> 1 A*B
#
# ValueError: operands could not be broadcast together with shapes (2,2) (2,3)

# %%
A@B
# Out:
# array([[ 7,  8,  8],
#        [ 6,  9, -1]])

# %%
B@A
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_38079/2247667524.py in <module>
# ----> 1 B@A
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 3)
