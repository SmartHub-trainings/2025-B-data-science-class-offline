# %%
A={4,7,3,2,4,15}

# %%
A
# Out:
# {2, 3, 4, 7, 15}

# %%
len(A)
# Out:
# 5

# %%
A= {1,7,9,4}
B={2,15,3,4,7}

# %%
A.intersection(B)
# Out:
# {4, 7}

# %%
B.intersection(A)
# Out:
# {4, 7}

# %%
C= {3,20,15}

# %%
A.intersection(C)
# Out:
# set()

# %%
A.union(B)
# Out:
# {1, 2, 3, 4, 7, 9, 15}

# %%
A.union(B).union(C) # method chaining
# Out:
# {1, 2, 3, 4, 7, 9, 15, 20}

# %%
A.difference(B)
# Out:
# {1, 9}

# %%
B.difference(A)
# Out:
# {2, 3, 15}

# %%
## Symmetric difference

# %%
A.union(B)
# Out:
# {1, 2, 3, 4, 7, 9, 15}

# %%
A.intersection(B)
# Out:
# {4, 7}

# %%
#A symm B={1,2,3,9,15}

# %%
A.symmetric_difference(B)
# Out:
# {1, 2, 3, 9, 15}

# %% [markdown]
# # Numpy

# %%
## illustration

# %%
a=[3,5,6,2,1]
b=[5,6,8,4,-3]
# c=[8,11,14,6,-2]

# %%
c=[]
for item in zip(a,b):
    c.append(item[0]+item[1])
print(c)
# Out:
# [8, 11, 14, 6, -2]

# %%
v=[6,7]

# %%
x1=v[0]
x2=v[1]
print(x1)
print(x2)
# Out:
# 6
# 7

# %%
## unpacking

# %%
v
# Out:
# [6, 7]

# %%
x3, x4= v

# %%
x3
# Out:
# 6

# %%
x4
# Out:
# 7

# %%
z=[4,6,4]
x1,x2,x3=z
print(x1)
print(x2)
print(x3)
# Out:
# 4
# 6
# 4

# %%
z=[4,6,4]
x1,x2,_=z
print(x1)
print(x2)
# Out:
# 4
# 6

# %%
x5,*x6=z

# %%
x5
# Out:
# 4

# %%
x6
# Out:
# [6, 4]

# %%
c=[]
for x,y in zip(a,b):
    c.append(x+y)
print(c)
# Out:
# [8, 11, 14, 6, -2]

# %%
c=[]
for x,y in zip(a,b):
    c.append(x*y)
print(c)
# Out:
# [15, 30, 48, 8, -3]

# %%
c=[]
for x,y in zip(a,b):
    c.append(x/y)
print(c)
# Out:
# [0.6, 0.8333333333333334, 0.75, 0.5, -0.3333333333333333]

# %%
a+b # wrong
# Out:
# [3, 5, 6, 2, 1, 5, 6, 8, 4, -3]

# %%
import numpy as np

# %%
a=np.array([3,5,6,2,1])
b=np.array([5,6,8,4,-3])
a+b
# Out:
# array([ 8, 11, 14,  6, -2])

# %%
a*b
# Out:
# array([15, 30, 48,  8, -3])

# %%
a/b
# Out:
# array([ 0.6       ,  0.83333333,  0.75      ,  0.5       , -0.33333333])

# %%
a
# Out:
# array([3, 5, 6, 2, 1])

# %%
b
# Out:
# array([ 5,  6,  8,  4, -3])

# %%
a**2
# Out:
# array([ 9, 25, 36,  4,  1])

# %%
x6
# Out:
# [6, 4]

# %%
c*2
# Out:
# [0.6,
#  0.8333333333333334,
#  0.75,
#  0.5,
#  -0.3333333333333333,
#  0.6,
#  0.8333333333333334,
#  0.75,
#  0.5,
#  -0.3333333333333333]

# %%
c+c
# Out:
# [0.6,
#  0.8333333333333334,
#  0.75,
#  0.5,
#  -0.3333333333333333,
#  0.6,
#  0.8333333333333334,
#  0.75,
#  0.5,
#  -0.3333333333333333]

# %%
a
# Out:
# array([3, 5, 6, 2, 1])

# %%
2*a
# Out:
# array([ 6, 10, 12,  4,  2])
