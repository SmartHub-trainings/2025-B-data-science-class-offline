# %%
import numpy as np

# %%
x=  np.random.randint(2,20,10)

# %%
x
# Out:
# array([11,  6,  6, 18, 14,  4,  9, 19,  7, 16], dtype=int32)

# %%
x.mean()
# Out:
# np.float64(11.0)

# %%
x[1]=700

# %%
x
# Out:
# array([ 11, 700,   6,  18,  14,   4,   9,  19,   7,  16], dtype=int32)

# %%
x.mean()
# Out:
# np.float64(80.4)

# %%
x1=  np.random.randint(2,20,10)

# %%
x1
# Out:
# array([ 7, 17, 17,  2,  8, 15, 18,  7,  2,  9], dtype=int32)

# %%
x1.sort()

# %%
x1
# Out:
# array([ 2,  2,  7,  7,  8,  9, 15, 17, 17, 18], dtype=int32)

# %%
x1.median()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 x1.median()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'median'

# %%
np.median(x1)
# Out:
# np.float64(8.5)

# %%
x2=  np.random.randint(2,20,10)

# %%
x2
# Out:
# array([17,  7,  9, 19,  4, 16,  5,  3,  3, 19], dtype=int32)

# %%
np.median(x2)
# Out:
# np.float64(8.0)

# %%
x2.sort()

# %%
x2
# Out:
# array([ 3,  3,  4,  5,  7,  9, 16, 17, 19, 19], dtype=int32)
