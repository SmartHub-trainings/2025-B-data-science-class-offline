# %%
import numpy as np

# %%
x=np.array([2,7,1,5])

# %%
x
# Out:
# array([2, 7, 1, 5])

# %%
x.mean()
# Out:
# np.float64(3.75)

# %%
x=np.array([5,7,12,20])
f=np.array([2,1,3,4])
fx=f*x

# %%
f
# Out:
# array([2, 1, 3, 4])

# %%
x
# Out:
# array([ 5,  7, 12, 20])

# %%
fx
# Out:
# array([10,  7, 36, 80])

# %%
fx.sum()
# Out:
# np.int64(133)

# %%
f.sum()
# Out:
# np.int64(10)

# %%
fx.sum()/f.sum()
# Out:
# np.float64(13.3)
