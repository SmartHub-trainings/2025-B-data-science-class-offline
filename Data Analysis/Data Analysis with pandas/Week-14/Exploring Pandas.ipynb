# %%
import pandas as pd

# %%
df=pd.read_csv("SS_meridian.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass                  Name     Sex   Age  SibSp  \
# 0            1         0       3     Clark, Miss Mabel  female  22.9      2
# 1            2         1       3  Lewis, Miss Margaret  female  59.8      1
# 2            3         1       2     Garcia, Mrs. Anna  female   NaN      1
# 3            4         0       2   Parker, Mrs. Violet  female  27.7      0
# 4            5         1       1      Adams, Miss Rose  female  52.1      1
#
#    Parch   Ticket   Fare Cabin Embarked
# 0      1  SM70415   3.50   NaN        M
# 1      0  SM69589   4.35   NaN        L
# 2      0  SM43901  14.88   NaN        C
# 3      1  SM68491  26.51   NaN        L
# 4      1  SM16863  65.47   NaN        C

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                    Name     Sex   Age  \
# 686          687         1       1  Jackson, Lady Florence  female  34.6
# 687          688         0       2      Walker, Mr. Robert    male  34.6
# 688          689         1       1    Jackson, Lady Violet  female  45.7
# 689          690         1       1     Harris, Mrs. Gladys  female  43.2
# 690          691         0       3       Green, Mrs. Clara  female  33.1
#
#      SibSp  Parch   Ticket    Fare Cabin Embarked
# 686      0      0  SM85340  100.78   B72        C
# 687      2      0  SM95119   25.18   NaN        M
# 688      0      0  SM87624   48.47   NaN        L
# 689      0      0  SM59207   42.19   D20        M
# 690      0      0  SM30204    5.21   NaN        M

# %%
df.shape
# Out:
# (691, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 691 entries, 0 to 690
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  691 non-null    int64
#  1   Survived     691 non-null    int64
#  2   Pclass       691 non-null    int64
#  3   Name         691 non-null    object
#  4   Sex          691 non-null    object
#  5   Age          634 non-null    float64
#  6   SibSp        691 non-null    int64
#  7   Parch        691 non-null    int64
#  8   Ticket       691 non-null    object
#  9   Fare         691 non-null    float64
#  10  Cabin        149 non-null    object
#  11  Embarked     691 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 64.9+ KB

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False   True  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 686        False     False   False  False  False  False  False  False   False
# 687        False     False   False  False  False  False  False  False   False
# 688        False     False   False  False  False  False  False  False   False
# 689        False     False   False  False  False  False  False  False   False
# 690        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             57
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          542
# Embarked         0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             57
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          542
# Embarked         0
# dtype: int64

# %%
df["Sex"]
# Out:
# 0      female
# 1      female
# 2      female
# 3      female
# 4      female
#         ...
# 686    female
# 687      male
# 688    female
# 689    female
# 690    female
# Name: Sex, Length: 691, dtype: object

# %%
df.Sex
# Out:
# 0      female
# 1      female
# 2      female
# 3      female
# 4      female
#         ...
# 686    female
# 687      male
# 688    female
# 689    female
# 690    female
# Name: Sex, Length: 691, dtype: object

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      414
# female    277
# Name: count, dtype: int64

# %%
df["Sex"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Sex'>

# %%
df["Sex"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df.Age
# Out:
# 0      22.9
# 1      59.8
# 2       NaN
# 3      27.7
# 4      52.1
#        ...
# 686    34.6
# 687    34.6
# 688    45.7
# 689    43.2
# 690    33.1
# Name: Age, Length: 691, dtype: float64

# %%
df.Age>=25
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 686     True
# 687     True
# 688     True
# 689     True
# 690     True
# Name: Age, Length: 691, dtype: bool

# %%
(df.Age>=25).value_counts()
# Out:
# Age
# True     422
# False    269
# Name: count, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass                    Name     Sex   Age  \
# 0              1         0       3       Clark, Miss Mabel  female  22.9
# 1              2         1       3    Lewis, Miss Margaret  female  59.8
# 2              3         1       2       Garcia, Mrs. Anna  female   NaN
# 3              4         0       2     Parker, Mrs. Violet  female  27.7
# 4              5         1       1        Adams, Miss Rose  female  52.1
# ..           ...       ...     ...                     ...     ...   ...
# 686          687         1       1  Jackson, Lady Florence  female  34.6
# 687          688         0       2      Walker, Mr. Robert    male  34.6
# 688          689         1       1    Jackson, Lady Violet  female  45.7
# 689          690         1       1     Harris, Mrs. Gladys  female  43.2
# 690          691         0       3       Green, Mrs. Clara  female  33.1
#
#      SibSp  Parch   Ticket    Fare Cabin Embarked
# ...

# %%
df.sort_values("Fare")
# Out:
#      PassengerId  Survived  Pclass                   Name     Sex   Age  \
# 0              1         0       3      Clark, Miss Mabel  female  22.9
# 333          334         1       2   Anderson, Mr. Harold    male  10.1
# 339          340         0       3     Scott, Mr. Herbert    male  35.2
# 343          344         0       3     Young, Mr. William    male  49.7
# 57            58         0       3    Thomas, Mr. Herbert    male  38.8
# ..           ...       ...     ...                    ...     ...   ...
# 276          277         1       1     Lopez, Lady Violet  female   NaN
# 363          364         1       1      Young, Lady Mabel  female  40.9
# 51            52         1       1      Carter, Miss Anna  female  28.7
# 201          202         1       1    Robinson, Lady Mary  female  47.6
# 182          183         1       1  Walker, Countess Emma  female  32.2
#
#      SibSp  Parch   Ticket    Fare Cabin Embarked
# 0        2      1  SM70415    3.50   NaN        M
# ...

# %%
df.sort_values("Fare",ascending=False)
# Out:
#      PassengerId  Survived  Pclass                    Name     Sex   Age  \
# 182          183         1       1   Walker, Countess Emma  female  32.2
# 201          202         1       1     Robinson, Lady Mary  female  47.6
# 51            52         1       1       Carter, Miss Anna  female  28.7
# 363          364         1       1       Young, Lady Mabel  female  40.9
# 276          277         1       1      Lopez, Lady Violet  female   NaN
# ..           ...       ...     ...                     ...     ...   ...
# 218          219         1       3  Thompson, Mr. Lawrence    male   5.1
# 200          201         1       1     Green, Capt. Walter    male  36.1
# 198          199         0       3     Allen, Mr. Clarence    male  36.9
# 372          373         0       1       Thomas, Miss Ruth  female  46.5
# 0              1         0       3       Clark, Miss Mabel  female  22.9
#
#      SibSp  Parch   Ticket    Fare Cabin Embarked
# ...

# %%
df.sort_values("Fare",ascending=False).head(3)
# Out:
#      PassengerId  Survived  Pclass                   Name     Sex   Age  \
# 182          183         1       1  Walker, Countess Emma  female  32.2
# 201          202         1       1    Robinson, Lady Mary  female  47.6
# 51            52         1       1      Carter, Miss Anna  female  28.7
#
#      SibSp  Parch   Ticket    Fare Cabin Embarked
# 182      1      0  SM22672  203.15   C81        M
# 201      0      0  SM28030  179.71   C22        C
# 51       0      0  SM97994  178.89   C99        L

# %%
df.nlargest(3,columns="Fare")
# Out:
#      PassengerId  Survived  Pclass                   Name     Sex   Age  \
# 182          183         1       1  Walker, Countess Emma  female  32.2
# 201          202         1       1    Robinson, Lady Mary  female  47.6
# 51            52         1       1      Carter, Miss Anna  female  28.7
#
#      SibSp  Parch   Ticket    Fare Cabin Embarked
# 182      1      0  SM22672  203.15   C81        M
# 201      0      0  SM28030  179.71   C22        C
# 51       0      0  SM97994  178.89   C99        L

# %%
df.nsmallest(3,columns="Fare")
# Out:
#     PassengerId  Survived  Pclass                  Name     Sex   Age  SibSp  \
# 0             1         0       3     Clark, Miss Mabel  female  22.9      2
# 5             6         1       3    Harris, Miss Grace  female  30.9      0
# 25           26         1       3  Clark, Mrs. Winifred  female  16.5      2
#
#     Parch   Ticket  Fare Cabin Embarked
# 0       1  SM70415   3.5   NaN        M
# 5       2  SM34535   3.5   NaN        L
# 25      2  SM24984   3.5   NaN        C

# %%
df.nlargest(3,columns="Age")
# Out:
#      PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 392          393         1       1  Taylor, Countess Martha  female  74.0
# 24            25         1       1      Lewis, Lady Harriet  female  71.1
# 424          425         0       1     Jones, Lady Beatrice  female  69.8
#
#      SibSp  Parch   Ticket    Fare Cabin Embarked
# 392      0      0  SM76402  139.83   NaN        M
# 24       0      0  SM39603  133.21   A93        M
# 424      0      1  SM13617  104.91   C32        C
