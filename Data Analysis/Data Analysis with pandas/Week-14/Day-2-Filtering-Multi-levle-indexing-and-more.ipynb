# %%
import pandas as pd

# %%
df=pd.read_csv("SS_meridian.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass                  Name     Sex   Age  SibSp  \
# 0            1         0       3     Clark, Miss Mabel  female  22.9      2
# 1            2         1       3  Lewis, Miss Margaret  female  59.8      1
# 2            3         1       2     Garcia, Mrs. Anna  female   NaN      1
# 3            4         0       2   Parker, Mrs. Violet  female  27.7      0
# 4            5         1       1      Adams, Miss Rose  female  52.1      1
#
#    Parch   Ticket   Fare Cabin Embarked
# 0      1  SM70415   3.50   NaN        M
# 1      0  SM69589   4.35   NaN        L
# 2      0  SM43901  14.88   NaN        C
# 3      1  SM68491  26.51   NaN        L
# 4      1  SM16863  65.47   NaN        C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 691 entries, 0 to 690
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  691 non-null    int64
#  1   Survived     691 non-null    int64
#  2   Pclass       691 non-null    int64
#  3   Name         691 non-null    object
#  4   Sex          691 non-null    object
#  5   Age          634 non-null    float64
#  6   SibSp        691 non-null    int64
#  7   Parch        691 non-null    int64
#  8   Ticket       691 non-null    object
#  9   Fare         691 non-null    float64
#  10  Cabin        149 non-null    object
#  11  Embarked     691 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 64.9+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   691.000000  691.000000  691.000000  634.000000  691.000000
# mean    346.000000    0.573082    2.108538   31.534385    0.751085
# std     199.618803    0.494988    0.850285   14.198957    0.995051
# min       1.000000    0.000000    1.000000    0.500000    0.000000
# 25%     173.500000    0.000000    1.000000   21.225000    0.000000
# 50%     346.000000    1.000000    2.000000   31.600000    0.000000
# 75%     518.500000    1.000000    3.000000   40.775000    1.000000
# max     691.000000    1.000000    3.000000   74.000000    4.000000
#
#             Parch        Fare
# count  691.000000  691.000000
# mean     0.560058   35.100593
# std      0.802404   40.895254
# min      0.000000    3.500000
# 25%      0.000000    7.440000
# 50%      0.000000   15.070000
# 75%      1.000000   54.585000
# max      3.000000  203.150000

# %%
df.describe(include="object")
# Out:
#                     Name   Sex   Ticket Cabin Embarked
# count                691   691      691   149      691
# unique               637     2      688   131        3
# top     Green, Mr. Edwin  male  SM28837   C16        L
# freq                   3   414        2     3      279

# %%
df.shape
# Out:
# (691, 12)

# %%
df.Ticket.value_counts()
# Out:
# Ticket
# SM28837    2
# SM61505    2
# SM86556    2
# SM70415    1
# SM49405    1
#           ..
# SM51999    1
# SM27423    1
# SM45187    1
# SM50906    1
# SM30204    1
# Name: count, Length: 688, dtype: int64

# %%
df.describe(include=["object","int","float"])
# Out:
#         PassengerId    Survived      Pclass              Name   Sex  \
# count    691.000000  691.000000  691.000000               691   691
# unique          NaN         NaN         NaN               637     2
# top             NaN         NaN         NaN  Green, Mr. Edwin  male
# freq            NaN         NaN         NaN                 3   414
# mean     346.000000    0.573082    2.108538               NaN   NaN
# std      199.618803    0.494988    0.850285               NaN   NaN
# min        1.000000    0.000000    1.000000               NaN   NaN
# 25%      173.500000    0.000000    1.000000               NaN   NaN
# 50%      346.000000    1.000000    2.000000               NaN   NaN
# 75%      518.500000    1.000000    3.000000               NaN   NaN
# max      691.000000    1.000000    3.000000               NaN   NaN
#
#                Age       SibSp       Parch   Ticket        Fare Cabin Embarked
# ...

# %%
result=df.describe(include="all")

# %%
result.head()
# Out:
#         PassengerId    Survived      Pclass              Name   Sex  \
# count         691.0  691.000000  691.000000               691   691
# unique          NaN         NaN         NaN               637     2
# top             NaN         NaN         NaN  Green, Mr. Edwin  male
# freq            NaN         NaN         NaN                 3   414
# mean          346.0    0.573082    2.108538               NaN   NaN
#
#                Age       SibSp       Parch   Ticket        Fare Cabin Embarked
# count   634.000000  691.000000  691.000000      691  691.000000   149      691
# unique         NaN         NaN         NaN      688         NaN   131        3
# top            NaN         NaN         NaN  SM28837         NaN   C16        L
# freq           NaN         NaN         NaN        2         NaN     3      279
# mean     31.534385    0.751085    0.560058      NaN   35.100593   NaN      NaN

# %%
result.tail()
# Out:
#      PassengerId  Survived  Pclass Name  Sex     Age  SibSp  Parch Ticket  \
# min          1.0       0.0     1.0  NaN  NaN   0.500    0.0    0.0    NaN
# 25%        173.5       0.0     1.0  NaN  NaN  21.225    0.0    0.0    NaN
# 50%        346.0       1.0     2.0  NaN  NaN  31.600    0.0    0.0    NaN
# 75%        518.5       1.0     3.0  NaN  NaN  40.775    1.0    1.0    NaN
# max        691.0       1.0     3.0  NaN  NaN  74.000    4.0    3.0    NaN
#
#         Fare Cabin Embarked
# min    3.500   NaN      NaN
# 25%    7.440   NaN      NaN
# 50%   15.070   NaN      NaN
# 75%   54.585   NaN      NaN
# max  203.150   NaN      NaN

# %%
result["Age"]
# Out:
# count     634.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean       31.534385
# std        14.198957
# min         0.500000
# 25%        21.225000
# 50%        31.600000
# 75%        40.775000
# max        74.000000
# Name: Age, dtype: float64

# %%
result[["Age","Sex"]]
# Out:
#                Age   Sex
# count   634.000000   691
# unique         NaN     2
# top            NaN  male
# freq           NaN   414
# mean     31.534385   NaN
# std      14.198957   NaN
# min       0.500000   NaN
# 25%      21.225000   NaN
# 50%      31.600000   NaN
# 75%      40.775000   NaN
# max      74.000000   NaN

# %%
result
# Out:
#         PassengerId    Survived      Pclass              Name   Sex  \
# count    691.000000  691.000000  691.000000               691   691
# unique          NaN         NaN         NaN               637     2
# top             NaN         NaN         NaN  Green, Mr. Edwin  male
# freq            NaN         NaN         NaN                 3   414
# mean     346.000000    0.573082    2.108538               NaN   NaN
# std      199.618803    0.494988    0.850285               NaN   NaN
# min        1.000000    0.000000    1.000000               NaN   NaN
# 25%      173.500000    0.000000    1.000000               NaN   NaN
# 50%      346.000000    1.000000    2.000000               NaN   NaN
# 75%      518.500000    1.000000    3.000000               NaN   NaN
# max      691.000000    1.000000    3.000000               NaN   NaN
#
#                Age       SibSp       Parch   Ticket        Fare Cabin Embarked
# ...

# %%
result.iloc[1]
# Out:
# PassengerId    NaN
# Survived       NaN
# Pclass         NaN
# Name           637
# Sex              2
# Age            NaN
# SibSp          NaN
# Parch          NaN
# Ticket         688
# Fare           NaN
# Cabin          131
# Embarked         3
# Name: unique, dtype: object

# %%
result.loc["unique"]
# Out:
# PassengerId    NaN
# Survived       NaN
# Pclass         NaN
# Name           637
# Sex              2
# Age            NaN
# SibSp          NaN
# Parch          NaN
# Ticket         688
# Fare           NaN
# Cabin          131
# Embarked         3
# Name: unique, dtype: object

# %%
df.Embarked.unique()
# Out:
# array(['M', 'L', 'C'], dtype=object)

# %%
df.Sex.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df.Cabin.unique()
# Out:
# array([nan, 'A43', 'A66', 'B59', 'A86', 'E46', 'B25', 'A93', 'D88', 'A41',
#        'C99', 'B70', 'B62', 'D80', 'D82', 'C48', 'C60', 'A49', 'A21',
#        'C59', 'B60', 'A83', 'D94', 'B32', 'C16', 'A82', 'C77', 'D89',
#        'A20', 'D62', 'B79', 'F28', 'B83', 'E35', 'A39', 'C88', 'D54',
#        'B51', 'F40', 'C81', 'E23', 'C62', 'D52', 'A50', 'C68', 'C22',
#        'C21', 'A11', 'B85', 'D45', 'A77', 'A60', 'A19', 'B65', 'E38',
#        'C87', 'D97', 'E55', 'A63', 'C67', 'B91', 'D78', 'C18', 'C75',
#        'D81', 'D20', 'E62', 'A40', 'D24', 'A26', 'F32', 'F50', 'B46',
#        'B56', 'D53', 'D58', 'A35', 'B41', 'F29', 'A53', 'A65', 'A36',
#        'F65', 'E33', 'D44', 'B15', 'C32', 'A16', 'B93', 'A18', 'C37',
#        'B94', 'C14', 'C52', 'B27', 'D69', 'F70', 'F75', 'D14', 'B68',
#        'B54', 'E28', 'F27', 'D47', 'D51', 'B67', 'B82', 'B69', 'B99',
#        'B24', 'B20', 'B17', 'C38', 'B38', 'C27', 'D91', 'F45', 'A61',
# ...

# %% [markdown]
# ## finding Missing values

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False   True  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 686        False     False   False  False  False  False  False  False   False
# 687        False     False   False  False  False  False  False  False   False
# 688        False     False   False  False  False  False  False  False   False
# 689        False     False   False  False  False  False  False  False   False
# 690        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             57
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          542
# Embarked         0
# dtype: int64

# %%
df.Age.isna()
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 686    False
# 687    False
# 688    False
# 689    False
# 690    False
# Name: Age, Length: 691, dtype: bool

# %%
df[df.Age.isna()]
# Out:
#      PassengerId  Survived  Pclass                       Name     Sex  Age  \
# 2              3         1       2          Garcia, Mrs. Anna  female  NaN
# 17            18         1       3         Adams, Mr. William    male  NaN
# 43            44         0       2     Mitchell, Mr. Clarence    male  NaN
# 46            47         1       1   Garcia, Countess Harriet  female  NaN
# 47            48         0       3          Miller, Miss Anna  female  NaN
# 55            56         1       1          Evans, Miss Alice  female  NaN
# 67            68         0       3          Green, Mr. Thomas    male  NaN
# 73            74         1       2       Thompson, Mr. Arthur    male  NaN
# 77            78         1       1   Martinez, Countess Elsie  female  NaN
# 87            88         0       2          Walker, Mr. James    male  NaN
# 88            89         1       2        Anderson, Mr. Harry    male  NaN
# ...

# %%
df[df.Age.isna()].shape
# Out:
# (57, 12)

# %% [markdown]
# ## More on filtering and data selection

# %%
df[["Sex","PassengerId"]]
# Out:
#         Sex  PassengerId
# 0    female            1
# 1    female            2
# 2    female            3
# 3    female            4
# 4    female            5
# ..      ...          ...
# 686  female          687
# 687    male          688
# 688  female          689
# 689  female          690
# 690  female          691
#
# [691 rows x 2 columns]

# %%
df.loc[0]
# Out:
# PassengerId                    1
# Survived                       0
# Pclass                         3
# Name           Clark, Miss Mabel
# Sex                       female
# Age                         22.9
# SibSp                          2
# Parch                          1
# Ticket                   SM70415
# Fare                         3.5
# Cabin                        NaN
# Embarked                       M
# Name: 0, dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass                  Name     Sex   Age  SibSp  \
# 0            1         0       3     Clark, Miss Mabel  female  22.9      2
# 1            2         1       3  Lewis, Miss Margaret  female  59.8      1
# 2            3         1       2     Garcia, Mrs. Anna  female   NaN      1
# 3            4         0       2   Parker, Mrs. Violet  female  27.7      0
# 4            5         1       1      Adams, Miss Rose  female  52.1      1
#
#    Parch   Ticket   Fare Cabin Embarked
# 0      1  SM70415   3.50   NaN        M
# 1      0  SM69589   4.35   NaN        L
# 2      0  SM43901  14.88   NaN        C
# 3      1  SM68491  26.51   NaN        L
# 4      1  SM16863  65.47   NaN        C

# %%
df.loc[0:3]
# Out:
#    PassengerId  Survived  Pclass                  Name     Sex   Age  SibSp  \
# 0            1         0       3     Clark, Miss Mabel  female  22.9      2
# 1            2         1       3  Lewis, Miss Margaret  female  59.8      1
# 2            3         1       2     Garcia, Mrs. Anna  female   NaN      1
# 3            4         0       2   Parker, Mrs. Violet  female  27.7      0
#
#    Parch   Ticket   Fare Cabin Embarked
# 0      1  SM70415   3.50   NaN        M
# 1      0  SM69589   4.35   NaN        L
# 2      0  SM43901  14.88   NaN        C
# 3      1  SM68491  26.51   NaN        L

# %%
df.iloc[0:3]
# Out:
#    PassengerId  Survived  Pclass                  Name     Sex   Age  SibSp  \
# 0            1         0       3     Clark, Miss Mabel  female  22.9      2
# 1            2         1       3  Lewis, Miss Margaret  female  59.8      1
# 2            3         1       2     Garcia, Mrs. Anna  female   NaN      1
#
#    Parch   Ticket   Fare Cabin Embarked
# 0      1  SM70415   3.50   NaN        M
# 1      0  SM69589   4.35   NaN        L
# 2      0  SM43901  14.88   NaN        C

# %%
df.loc[0:3,0:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df.loc[0:3,0:3]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1378, in _LocIndexer._getitem_tuple(self, tup)
#    1375 if self._multi_take_opportunity(tup):
#    1376     return self._multi_take(tup)
# -> 1378 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1021, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
# ...

# %%
df.iloc[0:3,0:3]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       3
# 2            3         1       2

# %%
df.loc[0:2,"PassengerId":"Pclass"]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       3
# 2            3         1       2

# %%
df.loc[:2,:"Pclass"]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       3
# 2            3         1       2

# %%
df.Sex=="female"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 686     True
# 687    False
# 688     True
# 689     True
# 690     True
# Name: Sex, Length: 691, dtype: bool

# %%
df[df.Sex=="female"]
# Out:
#      PassengerId  Survived  Pclass                    Name     Sex   Age  \
# 0              1         0       3       Clark, Miss Mabel  female  22.9
# 1              2         1       3    Lewis, Miss Margaret  female  59.8
# 2              3         1       2       Garcia, Mrs. Anna  female   NaN
# 3              4         0       2     Parker, Mrs. Violet  female  27.7
# 4              5         1       1        Adams, Miss Rose  female  52.1
# ..           ...       ...     ...                     ...     ...   ...
# 685          686         1       1        Lee, Mrs. Violet  female  38.0
# 686          687         1       1  Jackson, Lady Florence  female  34.6
# 688          689         1       1    Jackson, Lady Violet  female  45.7
# 689          690         1       1     Harris, Mrs. Gladys  female  43.2
# 690          691         0       3       Green, Mrs. Clara  female  33.1
#
#      SibSp  Parch   Ticket    Fare Cabin Embarked
# ...

# %%
df.Age>23
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 686     True
# 687     True
# 688     True
# 689     True
# 690     True
# Name: Age, Length: 691, dtype: bool

# %%
df[df.Age>23].sort_values("Age")
# Out:
#      PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 155          156         0       3    Campbell, Mr. Richard    male  23.1
# 409          410         0       3       Taylor, Mr. Ernest    male  23.2
# 185          186         0       3     Adams, Mr. Frederick    male  23.2
# 205          206         1       1      Sanchez, Lady Agnes  female  23.3
# 397          398         1       2         Smith, Mr. Henry    male  23.3
# ..           ...       ...     ...                      ...     ...   ...
# 268          269         1       1         Green, Lady Rose  female  69.3
# 558          559         0       2     Perez, Mr. Frederick    male  69.7
# 424          425         0       1     Jones, Lady Beatrice  female  69.8
# 24            25         1       1      Lewis, Lady Harriet  female  71.1
# 392          393         1       1  Taylor, Countess Martha  female  74.0
#
#      SibSp  Parch   Ticket    Fare Cabin Embarked
# ...

# %%
df[df.Age>23 and df.Sex=="female"].sort_values("Age")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30596\386780912.py in ?()
# ----> 1 df[df.Age>23 and df.Sex=="female"].sort_values("Age")
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1578     @final
#    1579     def __nonzero__(self) -> NoReturn:
# -> 1580         raise ValueError(
#    1581             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1582             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1583         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[df.Age>23 & df.Sex=="female"].sort_values("Age")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)    360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# TypeError: unsupported operand type(s) for &: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
df[(df.Age>23) & (df.Sex=="female")].sort_values("Age")
# Out:
#      PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 205          206         1       1       Sanchez, Lady Agnes  female  23.3
# 373          374         1       2           Hall, Miss Anna  female  23.6
# 446          447         1       2        Miller, Mrs. Ethel  female  23.7
# 327          328         1       1  Martinez, Countess Edith  female  23.8
# 444          445         1       3       Wright, Mrs. Louisa  female  23.9
# ..           ...       ...     ...                       ...     ...   ...
# 601          602         1       1     Hernandez, Lady Alice  female  68.0
# 268          269         1       1          Green, Lady Rose  female  69.3
# 424          425         0       1      Jones, Lady Beatrice  female  69.8
# 24            25         1       1       Lewis, Lady Harriet  female  71.1
# 392          393         1       1   Taylor, Countess Martha  female  74.0
#
#      SibSp  Parch   Ticket    Fare Cabin Embarked
# ...

# %%
df[(df.Age>23) & (df.Age<70) & (df.Sex=="female")].sort_values("Age")
# Out:
#      PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 205          206         1       1       Sanchez, Lady Agnes  female  23.3
# 373          374         1       2           Hall, Miss Anna  female  23.6
# 446          447         1       2        Miller, Mrs. Ethel  female  23.7
# 327          328         1       1  Martinez, Countess Edith  female  23.8
# 222          223         1       1       Phillips, Miss Emma  female  23.9
# ..           ...       ...     ...                       ...     ...   ...
# 366          367         1       2         Taylor, Mrs. Mary  female  64.5
# 187          188         1       1      Thompson, Mrs. Agnes  female  65.9
# 601          602         1       1     Hernandez, Lady Alice  female  68.0
# 268          269         1       1          Green, Lady Rose  female  69.3
# 424          425         0       1      Jones, Lady Beatrice  female  69.8
#
#      SibSp  Parch   Ticket    Fare Cabin Embarked
# ...

# %% [markdown]
# ## manipulation of indices

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass                  Name     Sex   Age  SibSp  \
# 0            1         0       3     Clark, Miss Mabel  female  22.9      2
# 1            2         1       3  Lewis, Miss Margaret  female  59.8      1
# 2            3         1       2     Garcia, Mrs. Anna  female   NaN      1
# 3            4         0       2   Parker, Mrs. Violet  female  27.7      0
# 4            5         1       1      Adams, Miss Rose  female  52.1      1
#
#    Parch   Ticket   Fare Cabin Embarked
# 0      1  SM70415   3.50   NaN        M
# 1      0  SM69589   4.35   NaN        L
# 2      0  SM43901  14.88   NaN        C
# 3      1  SM68491  26.51   NaN        L
# 4      1  SM16863  65.47   NaN        C

# %%
df_1=df.set_index("PassengerId")

# %%
df_1.head()
# Out:
#              Survived  Pclass                  Name     Sex   Age  SibSp  \
# PassengerId
# 1                   0       3     Clark, Miss Mabel  female  22.9      2
# 2                   1       3  Lewis, Miss Margaret  female  59.8      1
# 3                   1       2     Garcia, Mrs. Anna  female   NaN      1
# 4                   0       2   Parker, Mrs. Violet  female  27.7      0
# 5                   1       1      Adams, Miss Rose  female  52.1      1
#
#              Parch   Ticket   Fare Cabin Embarked
# PassengerId
# 1                1  SM70415   3.50   NaN        M
# 2                0  SM69589   4.35   NaN        L
# 3                0  SM43901  14.88   NaN        C
# 4                1  SM68491  26.51   NaN        L
# 5                1  SM16863  65.47   NaN        C

# %%
df.set_index(["PassengerId","Sex"])
# Out:
#                     Survived  Pclass                    Name   Age  SibSp  \
# PassengerId Sex
# 1           female         0       3       Clark, Miss Mabel  22.9      2
# 2           female         1       3    Lewis, Miss Margaret  59.8      1
# 3           female         1       2       Garcia, Mrs. Anna   NaN      1
# 4           female         0       2     Parker, Mrs. Violet  27.7      0
# 5           female         1       1        Adams, Miss Rose  52.1      1
# ...                      ...     ...                     ...   ...    ...
# 687         female         1       1  Jackson, Lady Florence  34.6      0
# 688         male           0       2      Walker, Mr. Robert  34.6      2
# 689         female         1       1    Jackson, Lady Violet  45.7      0
# 690         female         1       1     Harris, Mrs. Gladys  43.2      0
# 691         female         0       3       Green, Mrs. Clara  33.1      0
#
#                     Parch   Ticket    Fare Cabin Embarked
# ...

# %%
df.set_index(["Sex","PassengerId"])
# Out:
#                     Survived  Pclass                    Name   Age  SibSp  \
# Sex    PassengerId
# female 1                   0       3       Clark, Miss Mabel  22.9      2
#        2                   1       3    Lewis, Miss Margaret  59.8      1
#        3                   1       2       Garcia, Mrs. Anna   NaN      1
#        4                   0       2     Parker, Mrs. Violet  27.7      0
#        5                   1       1        Adams, Miss Rose  52.1      1
# ...                      ...     ...                     ...   ...    ...
#        687                 1       1  Jackson, Lady Florence  34.6      0
# male   688                 0       2      Walker, Mr. Robert  34.6      2
# female 689                 1       1    Jackson, Lady Violet  45.7      0
#        690                 1       1     Harris, Mrs. Gladys  43.2      0
#        691                 0       3       Green, Mrs. Clara  33.1      0
#
#                     Parch   Ticket    Fare Cabin Embarked
# ...

# %%
df.sort_values("Sex").set_index(["Sex","PassengerId"])
# Out:
#                     Survived  Pclass                  Name   Age  SibSp  \
# Sex    PassengerId
# female 1                   0       3     Clark, Miss Mabel  22.9      2
#        363                 1       2  Phillips, Mrs. Edith  17.8      1
#        360                 0       3      Clark, Miss Rose  18.9      4
#        358                 0       3     Davis, Miss Alice  18.9      0
#        356                 1       1    Sanchez, Miss Mary  38.8      0
# ...                      ...     ...                   ...   ...    ...
# male   369                 1       3   Collins, Mr. Thomas  16.8      0
#        118                 0       3  Robinson, Mr. Thomas  15.5      3
#        120                 1       3       Lopez, Mr. John  39.3      2
#        122                 1       1  Campbell, Col. Edwin  43.4      0
#        346                 0       3      Miller, Mr. John  29.8      0
#
#                     Parch   Ticket   Fare Cabin Embarked
# Sex    PassengerId
# ...
