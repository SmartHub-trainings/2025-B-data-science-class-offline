# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({"week1":np.random.randint(1,20,7),"week 2":np.random.randint(1,20,7)})

# %%
df
# Out:
#    week1  week 2
# 0      5       1
# 1      5      19
# 2     16      12
# 3      1      16
# 4      8       5
# 5      5      18
# 6     16       6

# %%
df.head()
# Out:
#    week1  week 2
# 0      5       1
# 1      5      19
# 2     16      12
# 3      1      16
# 4      8       5

# %%
df.tail()
# Out:
#    week1  week 2
# 2     16      12
# 3      1      16
# 4      8       5
# 5      5      18
# 6     16       6

# %%
df.head(2)
# Out:
#    week1  week 2
# 0      5       1
# 1      5      19

# %%
df.sample()
# Out:
#    week1  week 2
# 4      8       5

# %%
df.sample(3)
# Out:
#    week1  week 2
# 6     16       6
# 2     16      12
# 0      5       1

# %%
df.sample(3)
# Out:
#    week1  week 2
# 0      5       1
# 2     16      12
# 5      5      18

# %%
list(df.index)
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
df.columns
# Out:
# Index(['week1', 'week 2'], dtype='object')

# %%
df.index=range(2,9)

# %%
df
# Out:
#    week1  week 2
# 2      5       1
# 3      5      19
# 4     16      12
# 5      1      16
# 6      8       5
# 7      5      18
# 8     16       6

# %%
df.loc[2]
# Out:
# week1     5
# week 2    1
# Name: 2, dtype: int32

# %%
df.iloc[2]
# Out:
# week1     16
# week 2    12
# Name: 4, dtype: int32

# %%
df.week1
# Out:
# 2     5
# 3     5
# 4    16
# 5     1
# 6     8
# 7     5
# 8    16
# Name: week1, dtype: int32

# %%
df["week1"]
# Out:
# 2     5
# 3     5
# 4    16
# 5     1
# 6     8
# 7     5
# 8    16
# Name: week1, dtype: int32

# %%
df
# Out:
#    week1  week 2
# 2      5       1
# 3      5      19
# 4     16      12
# 5      1      16
# 6      8       5
# 7      5      18
# 8     16       6

# %%
df["week 2"]
# Out:
# 2     1
# 3    19
# 4    12
# 5    16
# 6     5
# 7    18
# 8     6
# Name: week 2, dtype: int32

# %%
df.columns =["week1","week2"]

# %%
df
# Out:
#    week1  week2
# 2      5      1
# 3      5     19
# 4     16     12
# 5      1     16
# 6      8      5
# 7      5     18
# 8     16      6

# %%
df["total"]=df.week1+ df.week2

# %%
df
# Out:
#    week1  week2  total
# 2      5      1      6
# 3      5     19     24
# 4     16     12     28
# 5      1     16     17
# 6      8      5     13
# 7      5     18     23
# 8     16      6     22

# %%
df["week1%"]= df.week1/df["total"]*100

# %%
df
# Out:
#    week1  week2  total     week1%
# 2      5      1      6  83.333333
# 3      5     19     24  20.833333
# 4     16     12     28  57.142857
# 5      1     16     17   5.882353
# 6      8      5     13  61.538462
# 7      5     18     23  21.739130
# 8     16      6     22  72.727273

# %%
df["dchdc"]=np.arange(7)*100

# %%
df
# Out:
#    week1  week2  total     week1%  dchdc
# 2      5      1      6  83.333333      0
# 3      5     19     24  20.833333    100
# 4     16     12     28  57.142857    200
# 5      1     16     17   5.882353    300
# 6      8      5     13  61.538462    400
# 7      5     18     23  21.739130    500
# 8     16      6     22  72.727273    600

# %%
df.drop("dchdc")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.drop("dchdc")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df.drop("dchdc",axis=1)

# %%
df.drop("dchdc",axis="columns",inplace=True)

# %%
df.drop("dchdc",axis=1,inplace=True)

# %%
df

# %%
df1=pd.read_csv("student.csv")

# %%
df1.head()
# Out:
#   STUDENT ID  1  2  3  4  5  6  7  8  9  ...  23  24  25  26  27  28  29  30  \
# 0   STUDENT1  2  2  3  3  1  2  2  1  1  ...   1   1   3   2   1   2   1   1
# 1   STUDENT2  2  2  3  3  1  2  2  1  1  ...   1   1   3   2   3   2   2   3
# 2   STUDENT3  2  2  2  3  2  2  2  2  4  ...   1   1   2   2   1   1   2   2
# 3   STUDENT4  1  1  1  3  1  2  1  2  1  ...   1   2   3   2   2   1   3   2
# 4   STUDENT5  2  2  1  3  2  2  1  3  1  ...   2   1   2   2   2   1   2   2
#
#    COURSE ID  GRADE
# 0          1      1
# 1          1      1
# 2          1      1
# 3          1      1
# 4          1      1
#
# [5 rows x 33 columns]

# %%
df1.shape
# Out:
# (145, 33)

# %%
df1
# Out:
#      STUDENT ID  1  2  3  4  5  6  7  8  9  ...  23  24  25  26  27  28  29  \
# 0      STUDENT1  2  2  3  3  1  2  2  1  1  ...   1   1   3   2   1   2   1
# 1      STUDENT2  2  2  3  3  1  2  2  1  1  ...   1   1   3   2   3   2   2
# 2      STUDENT3  2  2  2  3  2  2  2  2  4  ...   1   1   2   2   1   1   2
# 3      STUDENT4  1  1  1  3  1  2  1  2  1  ...   1   2   3   2   2   1   3
# 4      STUDENT5  2  2  1  3  2  2  1  3  1  ...   2   1   2   2   2   1   2
# ..          ... .. .. .. .. .. .. .. .. ..  ...  ..  ..  ..  ..  ..  ..  ..
# 140  STUDENT141  2  1  2  3  1  1  2  1  1  ...   1   1   2   1   2   1   3
# 141  STUDENT142  1  1  2  4  2  2  2  1  4  ...   1   1   3   2   2   1   5
# 142  STUDENT143  1  1  1  4  2  2  2  1  1  ...   1   1   3   3   2   1   4
# 143  STUDENT144  2  1  2  4  1  1  1  5  2  ...   2   1   2   1   2   1   5
# 144  STUDENT145  1  1  1  5  2  2  2  3  1  ...   2   1   3   2   3   1   5
#
#      30  COURSE ID  GRADE
# 0     1          1      1
# ...

# %%
df1.iloc[1]
# Out:
# STUDENT ID    STUDENT2
# 1                    2
# 2                    2
# 3                    3
# 4                    3
# 5                    1
# 6                    2
# 7                    2
# 8                    1
# 9                    1
# 10                   1
# 11                   2
# 12                   3
# 13                   2
# 14                   1
# 15                   2
# 16                   1
# 17                   2
# 18                   2
# 19                   2
# 20                   1
# 21                   1
# 22                   1
# 23                   1
# 24                   1
# 25                   3
# 26                   2
# 27                   3
# 28                   2
# 29                   2
# 30                   3
# COURSE ID            1
# GRADE                1
# Name: 1, dtype: object
