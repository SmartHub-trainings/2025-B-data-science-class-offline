# %%
import pandas as pd

# %%
# Series
# DataFrame

# %%
s1=pd.Series([4,5,6,4,6])
s2=pd.Series([3,-5,1,2,0])

# %%
s1
# Out:
# 0    4
# 1    5
# 2    6
# 3    4
# 4    6
# dtype: int64

# %%
s2
# Out:
# 0    3
# 1   -5
# 2    1
# 3    2
# 4    0
# dtype: int64

# %%
s1.dtype
# Out:
# dtype('int64')

# %%
s1.ndim
# Out:
# 1

# %%
s1.shape
# Out:
# (5,)

# %%
s1.size
# Out:
# 5

# %%
s1
# Out:
# 0    4
# 1    5
# 2    6
# 3    4
# 4    6
# dtype: int64

# %%
s1[0]
# Out:
# np.int64(4)

# %%
s1[3]
# Out:
# np.int64(4)

# %%
s1.index="abcde"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 s1.index="abcde"
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6335, in NDFrame.__setattr__(self, name, value)
#    6333 try:
#    6334     object.__getattribute__(self, name)
# -> 6335     return object.__setattr__(self, name, value)
#    6336 except AttributeError:
#    6337     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:816, in NDFrame._set_axis(self, axis, labels)
#     810 @final
#     811 def _set_axis(self, axis: AxisInt, labels: AnyArrayLike | list) -> None:
#     812     """
#     813     This is called from the cython code when we set the `index` attribute
#     814     directly, e.g. `series.index = [1, 2, 3]`.
#     815     """
# ...

# %%
s1.index=list("abcde")

# %%
s1.index=["a","b","c","d","e"]

# %%
s1
# Out:
# a    4
# b    5
# c    6
# d    4
# e    6
# dtype: int64

# %%
s1["a"]
# Out:
# np.int64(4)

# %%
s1[0]
# Out:
# C:\Users\georg\AppData\Local\Temp\ipykernel_7920\643609873.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s1[0]
# np.int64(4)

# %%
s3=pd.Series([3,5,4],index=[2,5,8])

# %%
s3
# Out:
# 2    3
# 5    5
# 8    4
# dtype: int64

# %%
s3[2]
# Out:
# np.int64(3)

# %%
s2.describe()
# Out:
# count    5.000000
# mean     0.200000
# std      3.114482
# min     -5.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      3.000000
# dtype: float64

# %%
s2
# Out:
# 0    3
# 1   -5
# 2    1
# 3    2
# 4    0
# dtype: int64
