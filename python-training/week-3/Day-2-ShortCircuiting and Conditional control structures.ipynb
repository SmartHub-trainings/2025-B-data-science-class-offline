# %% [markdown]
# ## Truthy and Falsy Values

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True+20
# Out:
# 21

# %%
True+True
# Out:
# 2

# %%
True*False
# Out:
# 0

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(46)
# Out:
# True

# %%
bool(-576)
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool(" ")
# Out:
# True

# %%
bool("david")
# Out:
# True

# %%
bool([3,5])
# Out:
# True

# %%
bool((5,7,7))
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool(())
# Out:
# False

# %% [markdown]
# ## Short circuiting

# %%
True or 30
# Out:
# True

# %%
False or 30
# Out:
# 30

# %%
True and 100
# Out:
# 100

# %%
True and True
# Out:
# True

# %%
False and 100
# Out:
# False

# %%
False and False
# Out:
# False

# %% [markdown]
# ## Conditional Control Structures

# %% [markdown]
# * If statement

# %%
no_of_books=2
no_of_pen=5
total_amount =(no_of_books*100)+(no_of_pen*50)
total_amount
# Out:
# 450

# %%
no_of_books=20
no_of_pen=5
price_per_pen=50
price_per_book=100
total_amount =no_of_books*price_per_book+no_of_pen*price_per_pen
total_amount
# Out:
# 2250

# %%
no_of_books=2
no_of_pen=5
price_per_pen=50
price_per_book=100
total_amount =no_of_books*price_per_book+no_of_pen*price_per_pen
if total_amount>=500:
    discount = 0.1*total_amount
    total_amount=total_amount-discount
print(total_amount)
# Out:
# 450

# %%
no_of_books=10
no_of_pen=6
price_per_pen=50
price_per_book=100
total_amount =no_of_books*price_per_book+no_of_pen*price_per_pen
if total_amount>=500:
    discount = 0.1*total_amount
    total_amount=total_amount-discount
print(total_amount)
# Out:
# 1170.0

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
no_of_books=10
no_of_pen=6
price_per_pen=50
price_per_book=100
total_amount =no_of_books*price_per_book+no_of_pen*price_per_pen
if total_amount>=500:
    #10% discount so the pay is 90% =0.9
    total_amount=total_amount*0.9
print(total_amount)
# Out:
# 1170.0

# %%
score = int(input("Enter a score: "))
if score >=50:
    remark="You passed!!"
print(remark)
# Out:
# Enter a score: 40
# You passed!!

# %%
remark
# Out:
# 'You passed!!'

# %%
score = int(input("Enter a score: "))
if score >=50:
    remark="You passed!!"
    print(remark)
# Out:
# Enter a score: 70
# You passed!!

# %%
score = int(input("Enter a score: "))
if score >=50:
    remark="You passed!!"
else:
    remark="You failed!!"
print(remark)
# Out:
# Enter a score: 12
# You failed!!

# %%
score = int(input("Enter a score: "))
if score >=50:remark="You passed!!"
else:remark="You failed!!"
print(remark)
