# %%
p=1000
t= 2
r=4.5
simple_interest=p*t*r/100
print(simple_interest)
# simpleInterest=
# SimpleInterest=
# Out:
# 90.0

# %%
amount = p+simple_interest
amount
# Out:
# 1090.0

# %%
name = "George"
state= 'Rivers'
bio ="""I like teaching...."""

# %%
name +state
# Out:
# 'GeorgeRivers'

# %%
name.upper()
# Out:
# 'GEORGE'

# %%
name.lower()
# Out:
# 'george'

# %%
name.swapcase()
# Out:
# 'gEORGE'

# %%
bio.title()
# Out:
# 'I Like Teaching....'

# %%
bio.capitalize()
# Out:
# 'I like teaching....'

# %% [markdown]
# ## Boolean/Logical data type

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
None

# %%
12==45
# Out:
# False

# %%
20==20.0
# Out:
# True

# %%
12>5
# Out:
# True

# %%
12>=45
# Out:
# False

# %%
"Smith"=="smith"
# Out:
# False

# %%
"smith">"Smith"
# Out:
# True

# %%
"Smith">"smith"
# Out:
# False

# %%
12==6 and "a">"A"
# Out:
# False

# %%
12==6 or "a">"A"
# Out:
# True
