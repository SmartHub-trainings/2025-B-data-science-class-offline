# %%
def compute_product(a,b,c):
    result =a*b*c
    print(result)

# %%
compute_product(2,5,4)
# Out:
# 40

# %%
compute_product(90,0,3)
# Out:
# 0

# %%
compute_product(3,1,3)
# Out:
# 9

# %%
y=compute_product(3,2,3)
# Out:
# 18

# %%
y+20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_15416/1858766926.py in <module>
# ----> 1 y+20
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
print(y)
# Out:
# None

# %%
def compute_product(a,b,c):
    result =a*b*c
    return result

# %%
compute_product(4,6,3)
# Out:
# 72

# %%
z=compute_product(4,6,3)

# %%
z+40
# Out:
# 112

# %%
z*2
# Out:
# 144

# %%
z
# Out:
# 72

# %%
compute_product(4,6,3)*2-100
# Out:
# 44

# %%
def do_things():
    print(40)
    print(10)
    return 2

# %%
do_things()
# Out:
# 40
# 10
# 2

# %%
r=do_things()
# Out:
# 40
# 10

# %%
r
# Out:
# 2

# %%
def do_things():
    return 40
    return 10
    return 2

# %%
d=do_things()

# %%
d
# Out:
# 40

# %%
def do_things_2():
    yield 40
    yield 10
    yield 2

# %%
z=do_things_2()

# %%
z
# Out:
# <generator object do_things_2 at 0x7fe7dde2aeb0>

# %%
next(z)
# Out:
# 40

# %%
next(z)
# Out:
# 10

# %%
next(z)
# Out:
# 2

# %%
next(z)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_15416/3467732745.py in <module>
# ----> 1 next(z)
#
# StopIteration:

# %%
compute_product(3,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_15416/1702732596.py in <module>
# ----> 1 compute_product(3,5)
#
# TypeError: compute_product() missing 1 required positional argument: 'c'

# %%
compute_product(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_15416/2921033817.py in <module>
# ----> 1 compute_product(4)
#
# TypeError: compute_product() missing 2 required positional arguments: 'b' and 'c'

# %%
def add_3(a,b,c):
    return a+b+c

# %%
add_3(3,5,4)
# Out:
# 12

# %%
add_3(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_15416/1883888077.py in <module>
# ----> 1 add_3(3)
#
# TypeError: add_3() missing 2 required positional arguments: 'b' and 'c'

# %%
def add_3(a,b,c=0):
    return a+b+c

# %%
add_3(2,4,5)
# Out:
# 11

# %%
add_3(3,5)
# Out:
# 8

# %%
add_3(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_15416/1883888077.py in <module>
# ----> 1 add_3(3)
#
# TypeError: add_3() missing 1 required positional argument: 'b'

# %%
def add_3(a,b=0,c=0):
    return a+b+c

# %%
add_3(4)
# Out:
# 4

# %%
add_3(5,6)
# Out:
# 11

# %%
add_3(5,3,2)
# Out:
# 10

# %%
def send_message(message,name):
    return f"{name}: {message}"

# %%
send_message("Stop coming late","Kosi")
# Out:
# 'Kosi: Stop coming late'

# %%
send_message("Please, come late. We need more money.","Victory")
# Out:
# 'Victory: Please, come late. We need more money.'

# %%
send_message("Stop coming late")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_15416/1884945593.py in <module>
# ----> 1 send_message("Stop coming late")
#
# TypeError: send_message() missing 1 required positional argument: 'name'

# %%
def send_message(message,name="Jane Doe"):
    return f"{name}: {message}"

# %%
send_message("Stop coming late","Kosi")
# Out:
# 'Kosi: Stop coming late'

# %%
send_message("Please, come late. We need more money.","Victory")
# Out:
# 'Victory: Please, come late. We need more money.'

# %%
send_message("Please, i will be late today. I have to go pick up my kids.")
# Out:
# 'Jane Doe: Please, i will be late today. I have to go pick up my kids.'

# %%
def add_3(a,b=0,c=0):
    print(a)
    print(b)
    print(c)

# %%
add_3(4)
# Out:
# 4
# 0
# 0

# %%
add_3(4,-3)
# Out:
# 4
# -3
# 0

# %%
add_3(4,c=5,b=8)
# Out:
# 4
# 8
# 5

# %% [markdown]
# Q 81: Write a function that takes the lengths of the two shorter sides of a right triangle as
# its parameters. Return the hypotenuse of the triangle, computed using Pythagorean
# theorem, as the function’s result. Include a main program that reads the lengths of
# the shorter sides of a right triangle from the user, uses your function to compute the
# length of the hypotenuse, and displays the result.m

# %%
def get_hypo(opposite,adjascent):
    hyp=  (opposite**2+adjascent**2)**0.5
    return hyp

# %%
get_hypo(3,4)
# Out:
# 5.0
