# %%
props ={"name":"George","number of children":10e4,"occupation":"Teacher",
        "hobbies":["Dancing","Singing","Seeing movies"]}

# %%
props
# Out:
# {'name': 'George',
#  'number of children': 100000.0,
#  'occupation': 'Teacher',
#  'hobbies': ['Dancing', 'Singing', 'Seeing movies']}

# %%
props["name"]
# Out:
# 'George'

# %%
props["occupation"]
# Out:
# 'Teacher'

# %%
props["name"]="Dan Smith"

# %%
props
# Out:
# {'name': 'Dan Smith',
#  'number of children': 100000.0,
#  'occupation': 'Teacher',
#  'hobbies': ['Dancing', 'Singing', 'Seeing movies']}

# %%
props["hobbies"].append("Coding")

# %%
props
# Out:
# {'name': 'Dan Smith',
#  'number of children': 100000.0,
#  'occupation': 'Teacher',
#  'hobbies': ['Dancing', 'Singing', 'Seeing movies', 'Coding']}

# %%
props.keys()
# Out:
# dict_keys(['name', 'number of children', 'occupation', 'hobbies'])

# %%
props.items()
# Out:
# dict_items([('name', 'Dan Smith'), ('number of children', 100000.0), ('occupation', 'Teacher'), ('hobbies', ['Dancing', 'Singing', 'Seeing movies', 'Coding'])])

# %%
props.pop("name")
# Out:
# 'Dan Smith'

# %%
props
# Out:
# {'number of children': 100000.0,
#  'occupation': 'Teacher',
#  'hobbies': ['Dancing', 'Singing', 'Seeing movies', 'Coding']}

# %%
props["name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_86158/1129516315.py in <module>
# ----> 1 props["name"]
#
# KeyError: 'name'

# %%
n=[3,5,6,4]

# %%
n[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_86158/1660922685.py in <module>
# ----> 1 n[4]
#
# IndexError: list index out of range

# %%
props.get("hobbies")
# Out:
# ['Dancing', 'Singing', 'Seeing movies', 'Coding']

# %%
props.get("occupation")
# Out:
# 'Teacher'

# %%
print(props.get("name"))
# Out:
# None

# %%
props.get("name","John Doe")
# Out:
# 'John Doe'

# %%
props.get("hobbies","John Doe")
# Out:
# ['Dancing', 'Singing', 'Seeing movies', 'Coding']

# %% [markdown]
# ## Functions

# %%
def add(x,y):
    z=x+y
    print(z)

# %%
add(4,7)
# Out:
# 11

# %%
add(-2333,78)
# Out:
# -2255

# %%
add(6,7)
# Out:
# 13

# %%
def ishow_strength(name,age):
    if age>21:
        message=f"{name}, you're getting old."
    else:
        message =f"Woah!! {name}, and you're so strong and healthy."
    print(message)

# %%
ishow_strength("Gideon",34)
# Out:
# Gideon, you're getting old.

# %%
ishow_strength("Victory",78)
# Out:
# Victory, you're getting old.
