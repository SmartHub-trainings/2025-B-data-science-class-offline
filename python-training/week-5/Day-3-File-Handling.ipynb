# %% [markdown]
# 1. Write a program that takes a number as input and prints whether it's positive, negative, or zero.

# %% [markdown]
# 2. Write a program that determines if a year entered by the user is a leap year. (Hint: A leap year is divisible by 4, except for century years which must be divisible by 400).

# %%
year = int(input("Enter year: "))
if year % 4 ==0 and (year % 100 !=0 or year% 400==0):
    print(f"{year} is a leap year")
else:
    print(f"{year} is a leap year")
# Out:
# Enter year: 404
# 404 is a leap year

# %%
year = int(input("Enter year: "))
if year % 4 ==0:
    print(f"{year} is a leap year")
else:
    print(f"{year} is a leap year")
# Out:
# Enter year: 200
# 200 is a leap year

# %%
year = int(input("Enter year: "))
if year % 4 ==0: #and (year % 100 !=0 or year% 400==0):
    print(f"{year} is a leap year")
else:
    print(f"{year} is a leap year")

# %%
year = int(input("Enter year: "))
if year % 4 ==0: #and (year % 100 !=0 or year% 400==0):
    if year % 100==0 and year % 400!=0:
        print(f"{year} is not a leap year")
    else:
        print(f"{year} is a leap year")        
else:
    print(f"{year} is not a leap year")
# Out:
# Enter year: 404
# 404 is a leap year

# %% [markdown]
# 3. Create a program that compares two numbers and prints whether the first number is greater than, less than, or equal to the second number.

# %% [markdown]
# 5. Create a simple calculator that takes two numbers and an operator (+, -, *, /) as input and performs the corresponding operation.

# %%
numb1 =input("Enter a number: ")
numb2 =input("Enter another number: ")
op=input("Enter the operator(+,-,*,/)")
result = numb1+op+numb2
print(eval(result))
# Out:
# Enter a number: 78
# Enter another number: 2
# Enter the operator(+,-,*,/)*
# 156

# %%
eval("7+5")
# Out:
# 12

# %%
y=78

# %%
eval("y+7")
# Out:
# 85

# %% [markdown]
# 7. Create a program that determines if a triangle is equilateral (all sides equal), isosceles (two sides equal), or scalene (no sides equal) based on three side lengths.

# %% [markdown]
# 17. Write a program that checks if a phone number is in the format "XXX-XXX-XXXX" where X is a digit.

# %%
phone= input("Enter your phone number: ")
splitted_number=phone.split("-")
print(splitted_number)
are_lengths_ok=(len(splitted_number[0])==3 
              and len(splitted_number[1])==3
             and len(splitted_number[2])==4)

are_all_digits=(splitted_number[0].isdigit() 
              and splitted_number[1].isdigit()
             and splitted_number[2].isdigit())
if are_lengths_ok and are_all_digits:
    print("It's in the right format")
else:
    print("Do well na!!")
# Out:
# Enter your phone number: 564-67i-7668
# ['564', '67i', '7668']
# Do well na!!

# %%
(4+6+6
-4)
# Out:
# 12

# %% [markdown]
# # File input and Output

# %%
file_handler=open("names.txt","w")

# %%
file_handler=open("names.txt","w")
file_handler.write("1. Naza")
file_handler.write("2. Victory")
file_handler.write("3. Kosi")
file_handler.write("4. Gideon")
file_handler.close()

# %%
file_handler=open("names.txt","w")
file_handler.write("1. Naza\n")
file_handler.write("2. Victory\n")
file_handler.write("3. Kosi\n")
file_handler.write("4. Gideon\n")
file_handler.close()

# %%
file_handler=open("names.txt","a")
file_handler.write("5. Joseph\n")
file_handler.write("6. Best\n")

file_handler.close()

# %%
file_handler=open("names.txt")
content=file_handler.read()
print(content)
file_handler.close()
# Out:
# 1. Naza
# 2. Victory
# 3. Kosi
# 4. Gideon
# 5. Joseph
# 6. Best
# 7. George

# %%
content
# Out:
# '1. Naza\n2. Victory\n3. Kosi\n4. Gideon\n5. Joseph\n6. Best\n7. George\n'

# %%
file_handler=open("names.txt")
content=file_handler.readlines()
print(content)
file_handler.close()
# Out:
# ['1. Naza, 60\n', '2. Victory, 40\n', '3. Kosi, 50\n', '4. Gideon, 60\n', '5. Joseph, 39\n', '6. Best, 40\n', '7. George, 80\n']

# %%
file_handler=open("names.txt")
content=file_handler.readlines()
# print(content)
file_handler.close()
for record in content:
    print(record)
# Out:
# 1. Naza, 60
#
# 2. Victory, 40
#
# 3. Kosi, 50
#
# 4. Gideon, 60
#
# 5. Joseph, 39
#
# 6. Best, 40
#
# 7. George, 80

# %%
file_handler=open("names.txt")
content=file_handler.readlines()
# print(content)
file_handler.close()
for record in content:
    name = record.split(" ")[-2]
    score =int(record.split(" ")[-1])
    if score>50:
        remark ="Passed"
    else:
        remark="Failed"  
    print(f"{name} {remark}")
# Out:
# Naza, Passed
# Victory, Failed
# Kosi, Failed
# Gideon, Passed
# Joseph, Failed
# Best, Failed
# George, Passed

# %%
from random import randint
file_handler=open("names.txt","w")
file_handler.write(f"1. Naza {randint(1,100)}\n")
file_handler.write(f"2. Victory {randint(1,100)}\n")
file_handler.write(f"3. Kosi {randint(1,100)}\n")
file_handler.write(f"4. Gideon {randint(1,100)}\n")
file_handler.write(f"5. Joseph {randint(1,100)}\n")
file_handler.write(f"6. Best {randint(1,100)}\n")
file_handler.write(f"7. George {randint(1,100)}")
file_handler.close()

# %%
file_handler=open("names.txt")
content=file_handler.readlines()
# print(content)
file_handler.close()
for record in content:
    name = record.split(" ")[-2]
    score =int(record.split(" ")[-1])
    if score>50:
        remark ="Passed"
    else:
        remark="Failed"  
    print(f"{name} {remark}")
# Out:
# Naza Failed
# Victory Passed
# Kosi Passed
# Gideon Failed
# Joseph Failed
# Best Failed
# George Passed
