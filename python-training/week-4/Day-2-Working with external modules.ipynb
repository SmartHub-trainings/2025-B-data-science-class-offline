# %%
a=45
b=12
c =a/b

# %%
c
# Out:
# 3.75

# %%
round(c)
# Out:
# 4

# %%
round(c,1)
# Out:
# 3.8

# %%
round(4.65,1)
# Out:
# 4.7

# %%
pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_50790/3440806613.py in <module>
# ----> 1 pi
#
# NameError: name 'pi' is not defined

# %%
e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_50790/2740565805.py in <module>
# ----> 1 e
#
# NameError: name 'e' is not defined

# %%
sin(45)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_50790/2793928794.py in <module>
# ----> 1 sin(45)
#
# NameError: name 'sin' is not defined

# %%
from math import sin,pi,e

# %%
e
# Out:
# 2.718281828459045

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(45)
# Out:
# 0.8509035245341184

# %%
cos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_50790/2275403165.py in <module>
# ----> 1 cos
#
# NameError: name 'cos' is not defined

# %%
import math

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sin(45)
# Out:
# 0.8509035245341184

# %%
math.cos(45)
# Out:
# 0.5253219888177297

# %%
math.factorial(2)
# Out:
# 2

# %%
math.factorial(4)
# Out:
# 24

# %%
import math as victory

# %%
victory.ceil(3.7)
# Out:
# 4

# %%
victory.floor(3.7)
# Out:
# 3

# %%
victory.floor(-3.7)
# Out:
# -4

# %%
cos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_50790/2275403165.py in <module>
# ----> 1 cos
#
# NameError: name 'cos' is not defined

# %%
math.cos(4)
# Out:
# -0.6536436208636119

# %%
victory.cos(5)
# Out:
# 0.2836621854632263

# %%
from math import *

# %%
cos(56)
# Out:
# 0.853220107722584

# %%
factorial(6)
# Out:
# 720

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_10',
#  '_11',
#  '_12',
#  '_15',
#  '_16',
#  '_17',
#  '_18',
#  '_19',
#  '_2',
#  '_20',
#  '_21',
#  '_23',
#  '_24',
#  '_25',
#  '_26',
#  '_28',
#  '_29',
#  '_3',
#  '_31',
#  '_32',
#  '_4',
#  '_5',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'a',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'b',
#  'c',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
# ...

# %%
import random

# %%
random.randint(3,20)
# Out:
# 14

# %%
random.choice(["Rock","Papper","Scissors"])
# Out:
# 'Rock'

# %%
magic_number = random.randint(3,7)
for i in range(5):
    user_input=int(input("Make a guess(1-10): "))
    if user_input==magic_number:
        print("Great!!\nYou got it right!")
    else:
        print("Please, use your brain and try again.")
# Out:
# Make a guess(1-10): 5
# Please, use your brain and try again.
# Make a guess(1-10): 4
# Please, use your brain and try again.
# Make a guess(1-10): 7
# Great!!
# You got it right!
# Make a guess(1-10): mblfkj
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_50790/3756918651.py in <module>
#       1 magic_number = random.randint(3,7)
#       2 for i in range(5):
# ----> 3     user_input=int(input("Make a guess(1-10): "))
#       4     if user_input==magic_number:
#       5         print("Great!!\nYou got it right!")
#
# ValueError: invalid literal for int() with base 10: 'mblfkj'

# %%
ll=3
ul=20
magic_number = random.randint(ll,ul)
for i in range(5):
    user_input=int(input(f"Make a guess({ll}-{ul}): "))
    if user_input==magic_number:
        print("Great!!\nYou got it right!")
        break
    else:
        print("Please, use your brain and try again.")
# Out:
# Make a guess(3-20): 4
# Please, use your brain and try again.
# Make a guess(3-20): 6
# Please, use your brain and try again.
# Make a guess(3-20): 7
# Please, use your brain and try again.
# Make a guess(3-20): 7
# Please, use your brain and try again.
# Make a guess(3-20): 23
# Please, use your brain and try again.
