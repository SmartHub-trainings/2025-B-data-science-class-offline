# %%
length =20
width =25
area=length * width
print(area)
# Out:
# 500

# %%
length =20
width =25
area=length * width
print("The area of the house is",area)
# Out:
# The area of the house is 500

# %%
length =20
width =25
area_of_the_house=length * width
print("The area of the house is",area_of_the_house)
# Out:
# The area of the house is 500

# %% [markdown]
# # User inputs

# %%
a= input()
print("You typed",a)
# Out:
# Danny
# You typed Danny

# %%
a= input()
b=input()
print("You typed",a,"and",b)
# Out:
# 3
# 45
# You typed 3 and 45

# %%
a= input()
b=input()
c= a+b
print(c)
# Out:
# 12
# 0
# 120

# %%
a= input()
b=input()
c= int(a)+int(b)
print(c)
# Out:
# 12
# 0
# 12

# %%
a= input("Enter the first number: ")
b=input("Enter the second number: ")
c= int(a)+int(b)
print("The sum of ",a,"and",b,"is",c)
# Out:
# Enter the first number: 5
# Enter the second number: 12
# The sum of  5 and 12 is 17

# %%
length =input("Enter the length of the room:")
width =input("Enter the width of the room: ")
area=int(length) * int(width)
print("The area of the house is",area)
# Out:
# Enter the length of the room:20
# Enter the width of the room: 30
# The area of the house is 600

# %%
length =input("Enter the length of the room:")
width =input("Enter the width of the room: ")
area=int(length) * int(width)
print("The area of the house is",area)
# Out:
# Enter the length of the room:2.5
# Enter the width of the room: 20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_16645/2544013095.py in <module>
#       1 length =input("Enter the length of the room:")
#       2 width =input("Enter the width of the room: ")
# ----> 3 area=int(length) * int(width)
#       4 print("The area of the house is",area)
#
# ValueError: invalid literal for int() with base 10: '2.5'

# %%
length =input("Enter the length of the room:")
width =input("Enter the width of the room: ")
area=float(length) * float(width)
print("The area of the house is",area)
# Out:
# Enter the length of the room:23.7
# Enter the width of the room: 67.3
# The area of the house is 1595.01
