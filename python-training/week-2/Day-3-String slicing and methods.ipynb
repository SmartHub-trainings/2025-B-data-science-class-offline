# %%
name ='Smith'

# %%
name[4]
# Out:
# 'h'

# %%
name[-5]
# Out:
# 'S'

# %%
name[-6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_83044/3277574988.py in <module>
# ----> 1 name[-6]
#
# IndexError: string index out of range

# %%
name[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/3d/pkg6m4_x11s9hw4jt5sb8zp00000gn/T/ipykernel_83044/891339142.py in <module>
# ----> 1 name[5]
#
# IndexError: string index out of range

# %%
name
# Out:
# 'Smith'

# %%
name[0]+name[1]+name[2] # Not a good way
# Out:
# 'Smi'

# %%
name[0:3:1]
# Out:
# 'Smi'

# %%
name[0:3:2]
# Out:
# 'Si'

# %%
name[:3:1]# default start is 0
# Out:
# 'Smi'

# %%
name[:3:] # default step is 1
# Out:
# 'Smi'

# %%
name[:3] # default step is 1
# Out:
# 'Smi'

# %%
name
# Out:
# 'Smith'

# %%
name[2:5]
# Out:
# 'ith'

# %%
name[2:]
# Out:
# 'ith'

# %%
name
# Out:
# 'Smith'

# %%
name[::-1]
# Out:
# 'htimS'

# %%
numbers ='0123456789'

# %%
numbers
# Out:
# '0123456789'

# %%
numbers[1::2]
# Out:
# '13579'

# %%
numbers[1::2]
# Out:
# '13579'

# %%
numbers[1::2][::-1]
# Out:
# '97531'

# %% [markdown]
# ## String methods

# %%
name
# Out:
# 'Smith'

# %%
name.upper()
# Out:
# 'SMITH'

# %%
name
# Out:
# 'Smith'

# %%
name.lower()
# Out:
# 'smith'

# %%
name.swapcase()
# Out:
# 'sMITH'

# %%
bio ="this is about me and you know it."

# %%
bio.title()
# Out:
# 'This Is About Me And You Know It.'

# %%
bio.capitalize()
# Out:
# 'This is about me and you know it.'

# %%
bio.count(" ")
# Out:
# 7

# %%
bio.count("a")
# Out:
# 2

# %%
bio.count("is")
# Out:
# 2

# %%
bio.count("our")
# Out:
# 0

# %%
bio.index("a")
# Out:
# 8

# %%
bio.index("is")
# Out:
# 2

# %%
"      this is cool      ".strip()
# Out:
# 'this is cool'

# %%
"      this is cool      ".strip()
# Out:
# 'this is cool'

# %%
"      this is cool      ".lstrip()
# Out:
# 'this is cool      '

# %%
"      this is cool      ".rstrip()
# Out:
# '      this is cool'

# %%
bio
# Out:
# 'this is about me and you know it.'

# %%
bio.split(" ")
# Out:
# ['this', 'is', 'about', 'me', 'and', 'you', 'know', 'it.']

# %%
bio.split("is")
# Out:
# ['th', ' ', ' about me and you know it.']
