# %%
type(20)
# Out:
# int

# %%
type(4.6)
# Out:
# float

# %%
type("this")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %% [markdown]
# # String Data type

# %%
surname="George"

# %%
first_name='Smith'

# %%
print(surname)
# Out:
# George

# %%
print(first_name)
# Out:
# Smith

# %% [markdown]
# ## String interpolation

# %%
surname
# Out:
# 'George'

# %%
first_name
# Out:
# 'Smith'

# %%
f"{surname} {first_name}"
# Out:
# 'George Smith'

# %%
f"{first_name}'s surname is {surname} and he's very fat."
# Out:
# "Smith's surname is George and he's very fat."

# %%
name = input("Enter a name: ")
age = input("Enter age: ")
sentence =f"Hey, {name}, you're {age} years of age"
print(sentence)
# Out:
# Enter a name: Danny
# Enter age: 39
# Hey, Danny, you're 39 years of age

# %% [markdown]
# ## String indexing and slicing

# %%
surname
# Out:
# 'George'

# %%
surname[0]
# Out:
# 'G'

# %%
surname[1]
# Out:
# 'e'

# %%
surname[2]
# Out:
# 'o'

# %%
surname
# Out:
# 'George'

# %%
len(surname)
# Out:
# 6

# %%
len("This is          great")
# Out:
# 22

# %% [markdown]
#  Ask a user to enter a sentence/phrase and print the last character in it.

# %%
sentence =input("Enter a sentence: ")
length = len(sentence)
last_character=sentence[length-1]
print(last_character)
# Out:
# Enter a sentence: Danny
# y

# %%
sentence =input("Enter a sentence: ")
last_character=sentence[-1]
print(last_character)
# Out:
# Enter a sentence: Do it
# t

# %%
first_name
# Out:
# 'Smith'

# %%
first_name[-1]
# Out:
# 'h'
